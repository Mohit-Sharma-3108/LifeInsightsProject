# %%
import sqlite3

# %%
conn = sqlite3.connect(r"C:\Users\Mohit\Desktop\Mohit\Projects\LifeInsightsProject\habit.db")

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

print(cursor.fetchall())
# Out:
# [('user',), ('habit',), ('habitlog',)]

# %%
cursor.execute("SELECT * FROM sqlite_master;")

for result in cursor.fetchall():
    print(result)
    print("***")
# Out:
# ('table', 'user', 'user', 2, 'CREATE TABLE user (\n\tid INTEGER NOT NULL, \n\tname VARCHAR NOT NULL, \n\tPRIMARY KEY (id)\n)')
# ***
# ('table', 'habit', 'habit', 3, 'CREATE TABLE habit (\n\tid INTEGER NOT NULL, \n\tname VARCHAR NOT NULL, \n\tmetric_type VARCHAR NOT NULL, \n\ttarget_minutes INTEGER NOT NULL, \n\ttarget_focus_score INTEGER NOT NULL, \n\tfrequency VARCHAR NOT NULL, \n\tis_frozen BOOLEAN NOT NULL, \n\tPRIMARY KEY (id)\n)')
# ***
# ('table', 'habitlog', 'habitlog', 4, 'CREATE TABLE habitlog (\n\tid INTEGER NOT NULL, \n\tuser_id INTEGER NOT NULL, \n\thabit_id INTEGER NOT NULL, \n\tvalue_minutes INTEGER NOT NULL, \n\tvalue_focus_score INTEGER NOT NULL, \n\tlog_date DATE NOT NULL, \n\tcreate_at DATETIME NOT NULL, \n\tPRIMARY KEY (id), \n\tFOREIGN KEY(user_id) REFERENCES user (id), \n\tFOREIGN KEY(habit_id) REFERENCES habit (id)\n)')
# ***

# %%
import streamlit as st
import json

# %%
st.set_page_config(page_title="CRUD app UI", layout="wide")
st.header("CRUD app UI")
goal = st.text_input("What is the goal that you are working towards?", placeholder="E.g Build a muscular body")

st.divider()

num_habits = st.slider(
    "How many habits do you want to track for this goal?",
    min_value=1,
    max_value=5,
    value=1
)

habits = []

for i in range(num_habits):
    st.subheader(f"Habit {i+1}")
    habit_name = st.text_input(
        f"Habit {i+1}",
        placeholder="E.g Go to the gym for 6o mins",
        key=f"habit_name_{i}"
    )
    habits.append({
        "habit_name": habit_name,
        "metrics": []
    })

st.divider()

st.subheader("How do you want to measure each habit?")

for i, habit in enumerate(habits):
    st.markdown(f"Habbit: **{habit['habit_name'] or 'Unnamed habbit'}**")

    num_metrics = st.number_input(
        f"How many metrics for '{habit['habit_name'] or 'this habit'}'?",
        min_value=1,
        max_value=3,
        step=1,
        key=f"num_metrics_{i}"
    )

    metrics = []

    for j in range(num_metrics):
        col1, col2 = st.columns(2)

        with col1:
            metric_name = st.text_input(
                f"Metric {j+1} name",
                placeholder="e.g Duration",
                key=f"metric_name_{i}_{j}"
            )
        with col2:
            metric_type = st.text_input(
                f"Metric type",
                ["number", "score (1-10)", "boolean", "text"],
                key=f"metric_type_{i}_{j}"
            )

        metrics.append({
            "metric_name": metric_name,
            "metric_type": metric_type
        })

    habits["metrics"] = metrics

st.divider()

habit_definition = {
    "goal": goal,
    "habits": habits
}


st.subheader("Generated defintion (JSON)")
st.json(habit_definition)

if st.button("Save"):
    st.success("Definition ready to save to DB")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
